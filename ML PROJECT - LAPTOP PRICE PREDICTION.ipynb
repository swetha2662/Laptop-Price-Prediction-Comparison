# %% [markdown]
# Importing packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
df = pd.read_csv('laptop_data.csv')

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
#no.of rows and columns
print("No.of rows and columns : ",df.shape)
# Out:
# No.of rows and columns :  (1303, 11)

# %%
#knowing the datatype of the attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.drop_duplicates()
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1269    Asus            Notebook    15.6
# 1270  Lenovo  2 in 1 Convertible    14.0
# 1271  Lenovo  2 in 1 Convertible    13.3
# 1272  Lenovo            Notebook    14.0
# 1273      HP            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1269                                    1366x768
# 1270   IPS Panel Full HD / Touchscreen 1920x1080
# ...

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# Removing the string in the values

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
plt.xlabel("Company")
plt.ylabel("Count")
df['Company'].value_counts().plot(kind='bar').set(title='COMPANY AND COUNT')
# Out:
# [Text(0.5, 1.0, 'COMPANY AND COUNT')]

# %%
sns.barplot(x=df['Company'],y=df['Price']).set(title='COMPANY VS PRICE')
plt.xticks(rotation='vertical')
plt.show()

# %%
plt.xlabel("Laptop Type")
plt.ylabel("Count")
df['TypeName'].value_counts().plot(kind='bar').set(title='COUNT OF TYPES')
# Out:
# [Text(0.5, 1.0, 'COUNT OF TYPES')]

# %%
sns.barplot(x=df['TypeName'],y=df['Price']).set(title='TYPE VS PRICE')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Inches'],y=df['Price']).set(title='INCHES VS PRICE')
# Out:
# [Text(0.5, 1.0, 'INCHES VS PRICE')]

# %%
df['ScreenResolution'].value_counts()
# Out:
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# 4K Ultra HD 3840x2160                              7
# Touchscreen 2560x1440                              7
# IPS Panel 1366x768                                 7
# IPS Panel Quad HD+ / Touchscreen 3200x1800         6
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Retina Display 2304x1440                 6
# Touchscreen 2256x1504                              6
# ...

# %% [markdown]
# Creating a new field In_Plane_Switching with the help of Screen Resolution

# %%
df['In_Plane_Switching'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)
df['ScreenResolution']=df['ScreenResolution'].str.findall(r'(\d+\.?\d+)')
df.tail()
# Out:
#      Company            TypeName  Inches ScreenResolution  \
# 1298  Lenovo  2 in 1 Convertible    14.0     [1920, 1080]
# 1299  Lenovo  2 in 1 Convertible    13.3     [3200, 1800]
# 1300  Lenovo            Notebook    14.0      [1366, 768]
# 1301      HP            Notebook    15.6      [1366, 768]
# 1302    Asus            Notebook    15.6      [1366, 768]
#
#                                        Cpu Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4           500GB HDD
#
#                         Gpu       OpSys Weight     Price  In_Plane_Switching
# 1298  Intel HD Graphics 520  Windows 10    1.8  33992.64                   1
# ...

# %%
df['ScreenResolution'].value_counts()
# Out:
# [1920, 1080]    841
# [1366, 768]     308
# [3840, 2160]     43
# [3200, 1800]     27
# [2560, 1440]     23
# [1600, 900]      23
# [2560, 1600]      6
# [2304, 1440]      6
# [2256, 1504]      6
# [1920, 1200]      5
# [1440, 900]       4
# [2880, 1800]      4
# [2400, 1600]      4
# [2160, 1440]      2
# [2736, 1824]      1
# Name: ScreenResolution, dtype: int64

# %%
df.corr()['Price']
# Out:
# Inches                0.068197
# Price                 1.000000
# In_Plane_Switching    0.252208
# Name: Price, dtype: float64

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %% [markdown]
# Creating a new field CPU Name from Cpu and finding the common brands of CPU

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)
df.drop(columns=['Cpu','Cpu Name'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches ScreenResolution Ram               Memory  \
# 0   Apple  Ultrabook    13.3     [2560, 1600]   8            128GB SSD
# 1   Apple  Ultrabook    13.3      [1440, 900]   8  128GB Flash Storage
# 2      HP   Notebook    15.6     [1920, 1080]   8            256GB SSD
# 3   Apple  Ultrabook    15.4     [2880, 1800]  16            512GB SSD
# 4   Apple  Ultrabook    13.3     [2560, 1600]   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080
#
#    In_Plane_Switching      Cpu brand
# 0                   1  Intel Core i5
# 1                   0  Intel Core i5
# 2                   0  Intel Core i5
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar').set(title='CPU BRAND VS COUNT')
# Out:
# [Text(0.5, 1.0, 'CPU BRAND VS COUNT')]

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price']).set(title='CPU BRAND VS PRICE')
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Ram'].value_counts().plot(kind='bar').set(title='RAM VALUE AND COUNT')
# Out:
# [Text(0.5, 1.0, 'RAM VALUE AND COUNT')]

# %%
sns.barplot(x=df['Ram'],y=df['Price']).set(title='RAM VALUE vs COUNT')
plt.xticks(rotation='vertical')
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %% [markdown]
# Splitting the entire Memory field into Presence(1) and absence(0) of the following : HDD, SSD, Flash_Storage, Flash

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.drop(columns=['Memory'],inplace=True)
df.head()
# Out:
#   Company   TypeName  Inches ScreenResolution Ram  \
# 0   Apple  Ultrabook    13.3     [2560, 1600]   8
# 1   Apple  Ultrabook    13.3      [1440, 900]   8
# 2      HP   Notebook    15.6     [1920, 1080]   8
# 3   Apple  Ultrabook    15.4     [2880, 1800]  16
# 4   Apple  Ultrabook    13.3     [2560, 1600]   8
#
#                             Gpu  OpSys Weight        Price  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080
#
#    In_Plane_Switching      Cpu brand  HDD  SSD  Hybrid  Flash_Storage
# 0                   1  Intel Core i5    0  128       0              0
# 1                   0  Intel Core i5    0    0       0            128
# 2                   0  Intel Core i5    0  256       0              0
# ...

# %%
df.corr()['Price']
# Out:
# Inches                0.068197
# Price                 1.000000
# In_Plane_Switching    0.252208
# HDD                  -0.096441
# SSD                   0.670799
# Hybrid                0.007989
# Flash_Storage        -0.040511
# Name: Price, dtype: float64

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %% [markdown]
# Splitting and dividing the GPU Brands

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])
df.head()
# Out:
#   Company   TypeName  Inches ScreenResolution Ram  \
# 0   Apple  Ultrabook    13.3     [2560, 1600]   8
# 1   Apple  Ultrabook    13.3      [1440, 900]   8
# 2      HP   Notebook    15.6     [1920, 1080]   8
# 3   Apple  Ultrabook    15.4     [2880, 1800]  16
# 4   Apple  Ultrabook    13.3     [2560, 1600]   8
#
#                             Gpu  OpSys Weight        Price  \
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# 3            AMD Radeon Pro 455  macOS   1.83  135195.3360
# 4  Intel Iris Plus Graphics 650  macOS   1.37   96095.8080
#
#    In_Plane_Switching      Cpu brand  HDD  SSD  Hybrid  Flash_Storage  \
# 0                   1  Intel Core i5    0  128       0              0
# 1                   0  Intel Core i5    0    0       0            128
# 2                   0  Intel Core i5    0  256       0              0
# ...

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median).set(title='GPU VS PRICE')
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price']).set(title='OPERATING SYSTEM VS PRICE')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Categorizing the Operating Systems

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['OS'] = df['OpSys'].apply(cat_os)
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['OS'],y=df['Price']).set(title='OS VS PRICE')
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.scatterplot(x=df['Weight'],y=df['Price']).set(title='WEIGHT VS PRICE')
# Out:
# [Text(0.5, 1.0, 'WEIGHT VS PRICE')]

# %% [markdown]
# Importing the necessary packages for the algorithms

# %%
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,accuracy_score

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
X=df[['Company','TypeName','Ram','Weight','In_Plane_Switching','Cpu brand','HDD','SSD','Gpu brand','OS']]
y=df['Price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

from sklearn.preprocessing import LabelEncoder

ohe=OneHotEncoder(handle_unknown = 'ignore')
ohe.fit(df[['Company','TypeName','Cpu brand','Gpu brand','OS']])
 
ohe.categories_
# Out:
# [array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#         'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
#         'Razer', 'Samsung', 'Toshiba', 'Vero', 'Xiaomi'], dtype=object),
#  array(['2 in 1 Convertible', 'Gaming', 'Netbook', 'Notebook', 'Ultrabook',
#         'Workstation'], dtype=object),
#  array(['AMD Processor', 'Intel Core i3', 'Intel Core i5', 'Intel Core i7',
#         'Other Intel Processor'], dtype=object),
#  array(['AMD', 'Intel', 'Nvidia'], dtype=object),
#  array(['Mac', 'Others/No OS/Linux', 'Windows'], dtype=object)]

# %% [markdown]
# Transforming the categorical values into numerical values

# %%
column_trans=make_column_transformer((OneHotEncoder(),
                                      ['Company','TypeName','Cpu brand','Gpu brand','OS']),remainder='passthrough')

# %% [markdown]
# Linear Regression

# %%
lr=LinearRegression()
pipe1=make_pipeline(column_trans,lr)
pipe1.fit(X_train,y_train)
lr_pred=pipe1.predict(X_test)
#lr_pred

print('r2_score : ',r2_score(y_test,lr_pred))
lr_accuracy=pipe1.score(X_test, y_test)*100
print('Accuracy : %.2f '%(lr_accuracy))
# Out:
# r2_score :  0.6860192382427631
# Accuracy : 68.60

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(15,7))
plt.plot(x_ax, y_test, lw=0.6, color="blue", label="original")
plt.plot(x_ax, lr_pred, lw=0.8, color="red", label="predicted")
plt.title("ORIGINAL DATA VS PREDICTED DATA")
plt.legend()
plt.show()

# %% [markdown]
# Decision Tree

# %%
step1 = make_column_transformer((OneHotEncoder(),
                                      ['Company','TypeName','Cpu brand','Gpu brand','OS']),remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe2 = Pipeline([('step1',step1),('step2',step2)])

pipe2.fit(X_train,y_train)

dt_pred = pipe2.predict(X_test)

print('r2_score : ',r2_score(y_test,dt_pred))
dt_accuracy=pipe2.score(X_test, y_test)*100
print('Accuracy : %.2f '%(dt_accuracy))
# Out:
# r2_score :  0.7651175787192674
# Accuracy : 76.51

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(15,7))
plt.plot(x_ax, y_test, lw=0.6, color="blue", label="original")
plt.plot(x_ax, dt_pred, lw=0.8, color="red", label="predicted")
plt.title("ORIGINAL DATA VS PREDICTED DATA")
plt.legend()
plt.show()

# %% [markdown]
# Random Forest

# %%
column_trans=make_column_transformer((OneHotEncoder(),
                                      ['Company','TypeName','Cpu brand','Gpu brand','OS']),remainder='passthrough')
        
Rf=RandomForestRegressor(n_estimators=100,random_state=3,max_samples=0.5,max_features=0.75,max_depth=15)    


pipe3=make_pipeline(column_trans,Rf)

pipe3.fit(X_train,y_train)

rf_pred = pipe3.predict(X_test)

print('r2_score : ',r2_score(y_test,rf_pred))
rf_accuracy=pipe3.score(X_test, y_test)*100
print('Accuracy : %.2f '%(rf_accuracy))
# Out:
# r2_score :  0.8033661664423768
# Accuracy : 80.34

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(15,7))
plt.plot(x_ax, y_test, lw=0.6, color="blue", label="original")
plt.plot(x_ax, rf_pred, lw=0.8, color="red", label="predicted")
plt.title("ORIGINAL DATA VS PREDICTED DATA")
plt.legend()
plt.show()

# %% [markdown]
# KNN

# %%
step1 =make_column_transformer((OneHotEncoder(),
                                      ['Company','TypeName','Cpu brand','Gpu brand','OS']),remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe4 = Pipeline([('step1',step1),('step2',step2)])

pipe4.fit(X_train,y_train)

knn_pred = pipe4.predict(X_test)

print('r2_score : ',r2_score(y_test,knn_pred))
knn_accuracy=pipe4.score(X_test, y_test)*100
print('Accuracy : %.2f '%(knn_accuracy))
# Out:
# r2_score :  0.7565641182024384
# Accuracy : 75.66

# %%
x_ax = range(len(y_test))
plt.figure(figsize=(15,7))
plt.plot(x_ax, y_test, lw=0.6, color="blue", label="original")
plt.plot(x_ax, lr_pred, lw=0.8, color="red", label="predicted")
plt.title("ORIGINAL DATA VS PREDICTED DATA")
plt.legend()
plt.show()

# %%
accuracy_scores = [lr_accuracy, dt_accuracy, rf_accuracy,knn_accuracy]

model_data = {'Model': ['Linear Regression','Decision Tree','Random Forest','KNN'],
              'Accuracy': accuracy_scores}
data = pd.DataFrame(model_data)

fig, ax1 = plt.subplots(figsize=(12,10))
ax1.set_title('Model Comparison: ACCURACY VS MODEL', fontsize=13)
color = 'tab:green'
ax1.set_xlabel('Model', fontsize=13)
ax1.set_ylabel('Accuracy', fontsize=13, color=color)
ax2 = sns.barplot(x='Model', y='Accuracy', data = data, palette='Pastel1')
ax1.tick_params(axis='y')
ax2 = ax1.twinx()
color = 'tab:red'
ax2 = sns.lineplot(x='Model', y='Accuracy', data = data, sort=False, color=color)
ax2.tick_params(axis='y', color=color)

# %% [markdown]
# <h3>Inference:</h3><br>
#  Random Forest model has the highest accuracy. So it best fits the dataset.
